# %% [markdown]
# # Movie Review Analysis

# %% [markdown]
# ## preprocessing and data cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\91964\Documents\codesoft\project_2\IMDb_Movies_India.csv", encoding="latin1")
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     NaN    NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0   8.00       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN    NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4  35.00          Ovais Khan       Prateik          Ishita Raj
# 4     NaN    NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df.iloc[7036]
# Out:
# Name        Kabhi Ajnabi Thé
# Year                 -1985.0
# Duration                 NaN
# Genre         Romance, Sport
# Rating                   5.0
# Votes                  14.00
# Director         Vijay Singh
# Actor 1       Poonam Dhillon
# Actor 2        Sandeep Patil
# Actor 3        Debashree Roy
# Name: 7036, dtype: object

# %%
df.iloc[9500]
# Out:
# Name        Moonlight: Unfortunately a Love Story
# Year                                      -2006.0
# Duration                                      NaN
# Genre                                      Comedy
# Rating                                        NaN
# Votes                                      $5.16M
# Director                          Raman Bharadwaj
# Actor 1                                Kim Sharma
# Actor 2                             Shekhar Suman
# Actor 3                         Perizaad Zorabian
# Name: 9500, dtype: object

# %%
df["Votes"].replace({"$5.16M":np.nan},inplace=True)
# Out:
# C:\Users\91964\AppData\Local\Temp\ipykernel_22964\2144794018.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Votes"].replace({"$5.16M":np.nan},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7919 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
df["Votes"]=pd.to_numeric(df["Votes"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7919 non-null   float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.2+ MB

# %%
df.Duration
# Out:
# 0            NaN
# 1        109 min
# 2         90 min
# 3        110 min
# 4        105 min
#           ...
# 15504        NaN
# 15505    129 min
# 15506        NaN
# 15507        NaN
# 15508    130 min
# Name: Duration, Length: 15509, dtype: object

# %%
#df["Year"]=pd.to_datetime(df["Year"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7919 non-null   float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.2+ MB

# %%
df['Duration'].replace({r'(\d*)min':r'\1'},inplace=True,regex=True)

# %%
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0     109             Drama
# 2                         #Homecoming -2021.0      90    Drama, Musical
# 3                             #Yaaram -2019.0     110   Comedy, Romance
# 4                   ...And Once Again -2010.0     105             Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     NaN    NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN    NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     NaN    NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df["Duration"]=pd.to_numeric(df["Duration"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   float64
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7919 non-null   float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7590
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.isna(),cmap="viridis")
plt.show()

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN       NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0     109.0            Drama
# 2                         #Homecoming -2021.0      90.0   Drama, Musical
# 3                             #Yaaram -2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again -2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     NaN    NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN    NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     NaN    NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
df["Year"]=abs(df["Year"])

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN       NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     NaN    NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN    NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     NaN    NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
#df['Year'] = df['Year'].astype('Int64')

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7590
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.describe()
# Out:
#                Year     Duration       Rating          Votes
# count  14981.000000  7240.000000  7919.000000    7919.000000
# mean    1987.012215   128.126519     5.841621    1938.520394
# std       25.416689    28.912724     1.381777   11602.415952
# min     1913.000000     2.000000     1.100000       5.000000
# 25%     1968.000000   110.000000     4.900000      16.000000
# 50%     1991.000000   131.000000     6.000000      55.000000
# 75%     2009.000000   147.000000     6.800000     404.000000
# max     2022.000000   321.000000    10.000000  591417.000000

# %%
df["Duration"]=df["Duration"].fillna(df["Duration"].median())

# %%
df["Rating"]=df["Rating"].fillna(df["Rating"].median())

# %%
df["Votes"]=df["Votes"].fillna(df["Votes"].median())

# %%
df.to_csv(r"C:\Users\91964\Documents\codesoft\project_2\hh2_IMDb_Movies_India.csv")

# %%
df["Genre"]=df["Genre"].fillna("Unknown")

# %%
df["Director"]=df["Director"].fillna("Unknown")

# %%
df["Actor 2"]=df["Actor 2"].fillna("Unknown")

# %%
df["Actor 3"]=df["Actor 3"].fillna("Unknown")

# %%
df["Actor 1"]=df["Actor 1"].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# Name          0
# Year        528
# Duration      0
# Genre         0
# Rating        0
# Votes         0
# Director      0
# Actor 1       0
# Actor 2       0
# Actor 3       0
# dtype: int64

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN     131.0            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     6.0   55.0       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.0   55.0  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.0   55.0        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df[df.duplicated()]
# Out:
#                             Name    Year  Duration     Genre  Rating  Votes  \
# 1250   Arab Ka Sona - Abu Kaalia  1979.0     131.0    Action     6.0   55.0
# 1769                     Balidan  1992.0     131.0     Drama     6.0   55.0
# 4723     First Time - Pehli Baar  2009.0     131.0   Unknown     6.0   55.0
# 9713                     Musafir     NaN     131.0  Thriller     6.0   55.0
# 13069                    Shivani  2019.0     131.0     Crime     6.0   55.0
# 13308          Slumdog Karodpati  2019.0     118.0  Thriller     6.0   55.0
#
#                   Director      Actor 1       Actor 2     Actor 3
# 1250        Master Bhagwan    Meena Rai    Dara Singh     Unknown
# 1769               Unknown      Unknown       Unknown     Unknown
# 4723          Raja Bundela  Zeenat Aman   Nitin Arora  Raj Babbar
# 9713           Shiva Dagar      Unknown       Unknown     Unknown
# 13069  Ugresh Prasad Ujala      Santosh       Unknown     Unknown
# ...

# %% [markdown]
# ## Visualisations

# %%
plt.figure(figsize=(16,3))
df['Year'].value_counts().sort_index().plot(kind='bar')
plt.title("Number of Movies per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
df["Year"].value_counts()
# Out:
# Year
# 2019.0    410
# 2021.0    392
# 2018.0    381
# 2017.0    360
# 2005.0    346
#          ...
# 1922.0      1
# 1913.0      1
# 1926.0      1
# 1914.0      1
# 1924.0      1
# Name: count, Length: 102, dtype: int64

# %% [markdown]
# ## heatmap after cleaning

# %%
plt.figure(figsize=(10,2))
sns.heatmap(df.isna(),cmap="viridis")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
sns.boxplot(df)
plt.yscale("log")

# %% [markdown]
# they were number of outliers in Duration,rating and votes

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN     131.0            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     6.0   55.0       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.0   55.0  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.0   55.0        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
def box(df):
    if df["Rating"]<4:
        return "Below_average"
    elif 4<df["Rating"]<7:
        return "Average"
    else:
        return "Hit"

# %%
df["Box_office"]=df.apply(box,axis=1)

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Box_office'],
#       dtype='object')

# %%
df["Box_office"].unique()
# Out:
# array(['Average', 'Hit', 'Below_average'], dtype=object)

# %% [markdown]
# > <b> Most of movies released in 2019,(410)movies

# %%
hitcount=df[df['Box_office']=='Hit'].groupby('Year').size()

# %%
df[df['Box_office']=='Hit'].groupby('Year').size().sort_values(ascending=False)
# Out:
# Year
# 2019.0    102
# 2018.0     80
# 2017.0     66
# 2020.0     61
# 2015.0     58
#          ...
# 1935.0      1
# 1936.0      1
# 1937.0      1
# 1934.0      1
# 1933.0      1
# Length: 88, dtype: int64

# %%
year=hitcount.idxmax()
count=hitcount.max()
print(f"Year {year} have {count} Hits ,its the year with most hits")
# Out:
# Year 2019.0 have 102 Hits ,its the year with most hits

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN     131.0            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     6.0   55.0       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.0   55.0  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.0   55.0        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3 Box_office
# 0  Rajendra Bhatia    Average
# 1    Arvind Jangid        Hit
# ...

# %%
df.to_csv(r"C:\Users\91964\Documents\codesoft\project_2\Cleaned_IMDb_Movies_India.csv")

# %%
plt.pie(df["Box_office"].value_counts(),autopct="%1.1f%%",startangle=90,labels=df["Box_office"].value_counts().index)
plt.ylabel("")
plt.title("Box Office Distribution")
plt.legend()
plt.show()

# %% [markdown]
# > <b> Year 2019 have 102 hits,its the year with most hits,2018 with 80 hits,2017 with 66 hits,2020 with 61 hits and 2015 58 hits

# %% [markdown]
# ## year 2019 anlysis

# %%
y2019=df[df["Year"]==2019].groupby("Box_office").size()

# %%
y2019
# Out:
# Box_office
# Average          289
# Below_average     19
# Hit              102
# dtype: int64

# %%
y2019/410*100
# Out:
# Box_office
# Average          70.487805
# Below_average     4.634146
# Hit              24.878049
# dtype: float64

# %% [markdown]
# > <b>  movies released in 2019,70% is average,4% is below average,24% is hit,indicating it was a best year for movie industry

# %%
plt.pie(y2019,autopct="%1.1f%%",labels=["Average","Below_average","Hit"])
plt.title("2019 Movie chart")
plt.show()

# %% [markdown]
# ## Most rated movie

# %%
df["Rating"].idxmax()
# Out:
# 8339

# %%
df.iloc[8339]
# Out:
# Name              Love Qubool Hai
# Year                       2020.0
# Duration                     94.0
# Genre              Drama, Romance
# Rating                       10.0
# Votes                         5.0
# Director          Saif Ali Sayeed
# Actor 1                 Ahaan Jha
# Actor 2            Mahesh Narayan
# Actor 3       Rajasree Rajakumari
# Box_office                    Hit
# Name: 8339, dtype: object

# %% [markdown]
# > <b> Details of movie with most rating

# %%
df["Rating"].idxmin()
# Out:
# 12171

# %%
df.iloc[12171]
# Out:
# Name                Sadak 2
# Year                 2020.0
# Duration              133.0
# Genre         Action, Drama
# Rating                  1.1
# Votes               67785.0
# Director       Mahesh Bhatt
# Actor 1          Alia Bhatt
# Actor 2       Priyanka Bose
# Actor 3         Sanjay Dutt
# Box_office    Below_average
# Name: 12171, dtype: object

# %% [markdown]
# > <b> Details of movie with wrost rating

# %% [markdown]
# ## Genere with Most Hits

# %%
gen=df[df["Box_office"]=="Hit"].groupby("Genre").size().sort_values(ascending=False).head()
gen
# Out:
# Genre
# Drama                   396
# Drama, Romance          111
# Action, Crime, Drama     77
# Drama, Family            72
# Comedy, Drama            71
# dtype: int64

# %% [markdown]
# > <b> most of hit movies are Drama genre

# %%
plt.figure(figsize=(12,3))
sns.barplot(gen,color="green")
plt.title("Genre with most hits")
plt.show()

# %% [markdown]
# > <b> Hit count vs genre Barplot

# %%
df.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN     131.0            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     6.0   55.0       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.0   55.0  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.0   55.0        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3 Box_office
# 0  Rajendra Bhatia    Average
# 1    Arvind Jangid        Hit
# ...

# %%
dr=df[df["Box_office"]=="Hit"].groupby("Director").size().sort_values(ascending=False).head()
dr
# Out:
# Director
# Hrishikesh Mukherjee    25
# Shyam Benegal           17
# Yash Chopra             14
# Gulzar                  14
# Basu Chatterjee         13
# dtype: int64

# %% [markdown]
# > <b>Hrishikesh Mukherjee has the most hit movies, with 25 to his credit.

# %%
plt.figure(figsize=(12,4))
sns.barplot(dr)
plt.title("most hitmovies directors")
plt.show()

# %%
bl=df[df["Box_office"]=="Below_average"].groupby("Director").size().sort_values(ascending=False).head()
bl
# Out:
# Director
# T.L.V. Prasad      10
# Ram Gopal Varma     8
# Vikram Bhatt        7
# Mohan Bhakri        6
# Mahesh Bhatt        6
# dtype: int64

# %%
plt.figure(figsize=(12,3))
sns.barplot(bl)
plt.title("Director with most below_average movies")
plt.show()

# %%
plt.figure(figsize=(13,3))
sns.barplot(df["Director"].value_counts().head())
plt.show()

# %% [markdown]
# > <b> Jayant Desai has directed more movies, but since I filled the null values with ‘Unknown’, he appears as the top contributor.

# %%
dll=df["Director"].value_counts().sort_values(ascending=False).head().drop(index="Unknown")

# %% [markdown]
# > <b> “By dropping the ‘Unknown’ entries, we can now see the accurate values

# %%
dll
# Out:
# Director
# Jayant Desai       58
# Kanti Shah         57
# Babubhai Mistry    50
# Mahesh Bhatt       48
# Name: count, dtype: int64

# %%
plt.figure(figsize=(13,3))
sns.barplot(dll)
plt.show()

# %% [markdown]
# > <b> “Jayant Desai made 58 movies, whereas Kanti Shah made 57.”

# %% [markdown]
# # Model building and evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor# machine learning algorithm
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split # model evaluationn
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score# Accuracy  
from sklearn.preprocessing import LabelEncoder

# %%
dfm=pd.read_csv(r"C:\Users\91964\Documents\codesoft\project_2\hh2_IMDb_Movies_India.csv")
dfm.head()
# Out:
#    Unnamed: 0                                Name    Year  Duration  \
# 0           0                                         NaN     131.0
# 1           1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2           2                         #Homecoming  2021.0      90.0
# 3           3                             #Yaaram  2019.0     110.0
# 4           4                   ...And Once Again  2010.0     105.0
#
#              Genre  Rating  Votes            Director       Actor 1  \
# 0            Drama     6.0   55.0       J.S. Randhawa      Manmauji
# 1            Drama     7.0    8.0       Gaurav Bakshi  Rasika Dugal
# 2   Drama, Musical     6.0   55.0  Soumyajit Majumdar  Sayani Gupta
# 3  Comedy, Romance     4.4   35.0          Ovais Khan       Prateik
# 4            Drama     6.0   55.0        Amol Palekar  Rajat Kapoor
#
#               Actor 2          Actor 3
# 0              Birbal  Rajendra Bhatia
# 1      Vivek Ghamande    Arvind Jangid
# ...

# %%
dfm["Director"].unique()
# Out:
# array(['J.S. Randhawa', 'Gaurav Bakshi', 'Soumyajit Majumdar', ...,
#        'Mozez Singh', 'Ved Prakash', 'Kiran Thej'],
#       shape=(5939,), dtype=object)

# %%
le=LabelEncoder()
dfm["Genre"]=le.fit_transform(dfm["Genre"])
for label,i in enumerate(le.classes_):
    print(f"{label}:{i}")
# Out:
# 0:Action
# 1:Action, Adventure
# 2:Action, Adventure, Biography
# 3:Action, Adventure, Comedy
# 4:Action, Adventure, Crime
# 5:Action, Adventure, Drama
# 6:Action, Adventure, Family
# 7:Action, Adventure, Fantasy
# 8:Action, Adventure, History
# 9:Action, Adventure, Horror
# 10:Action, Adventure, Musical
# 11:Action, Adventure, Mystery
# 12:Action, Adventure, Romance
# 13:Action, Adventure, Sci-Fi
# 14:Action, Adventure, Thriller
# 15:Action, Adventure, War
# 16:Action, Biography, Crime
# 17:Action, Biography, Drama
# 18:Action, Comedy
# 19:Action, Comedy, Crime
# 20:Action, Comedy, Drama
# 21:Action, Comedy, Fantasy
# 22:Action, Comedy, Horror
# 23:Action, Comedy, Musical
# 24:Action, Comedy, Mystery
# 25:Action, Comedy, Romance
# 26:Action, Comedy, Thriller
# 27:Action, Comedy, War
# 28:Action, Crime
# 29:Action, Crime, Drama
# 30:Action, Crime, Family
# 31:Action, Crime, Fantasy
# 32:Action, Crime, History
# 33:Action, Crime, Horror
# 34:Action, Crime, Musical
# ...

# %% [markdown]
# > <b> label guide for Genre

# %%
dfm["Director"]=le.fit_transform(dfm["Director"])
for label,i in enumerate(le.classes_):
    print(f"{label}:{i}")
# Out:
# 0:A B Arjun
# 1:A. Bhimsingh
# 2:A. Habib
# 3:A. Jagannathan
# 4:A. Karim
# 5:A. Kodandarami Reddy
# 6:A. Majid
# 7:A. Muthu
# 8:A. Raja
# 9:A. Rashid
# 10:A. Salaam
# 11:A. Shakoor
# 12:A. Shamsheer
# 13:A. Veerappan
# 14:A. Venkatesh
# 15:A. Zahoor
# 16:A.A. Darpan
# 17:A.C. Trilogchander
# 18:A.G. Surma
# 19:A.H. Essa
# 20:A.K. Bir
# 21:A.K. Hangal
# 22:A.K. Mishra
# 23:A.L. Vijay
# 24:A.M. Khan
# 25:A.M.R. Ramesh
# 26:A.N. Bannerjee
# 27:A.P. Nagarajan
# 28:A.P. Subbaraav
# 29:A.R. Kabuli
# 30:A.R. Kardar
# 31:A.R. Murugadoss
# 32:A.R. Sheikh
# 33:A.R. Zamindar
# 34:A.S. Arora
# 35:A.S.A. Sami
# 36:A.T. Joy
# 37:A.T. Raghu
# 38:Aadesh Vishwakarma
# 39:Aadish Keluskar
# 40:Aakash Bhatia
# 41:Aakash Chaturvedi
# 42:Aakash Gupta
# 43:Aakkoo
# 44:Aamir Bashir
# 45:Aamir Khan
# 46:Aamreeta Gautam
# 47:Aanand L. Rai
# 48:Aanand Raut
# 49:Aanchal Malhotra
# 50:Aanuj Tewari
# 51:Aarif Sheikh
# 52:Aarthi Agarwal
# 53:Aarti S. Bagdi
# 54:Aarti Shrivastava
# 55:Aarun Nagar
# ...

# %% [markdown]
# > label guide for director

# %%
fet=["Duration","Genre","Votes","Director"]
x=dfm[fet]
y=dfm["Rating"]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
xtrain
# Out:
#        Duration  Genre  Votes  Director
# 3485      141.0    361  293.0      2696
# 8701      131.0    313    5.0      2534
# 11179     116.0    299    5.0      4332
# 11628      90.0    299    5.0      4871
# 4819      131.0    299   55.0       415
# ...         ...    ...    ...       ...
# 5191      116.0      0   55.0      2431
# 13418     131.0     87   55.0      1315
# 5390      120.0    181   18.0      2994
# 860       131.0    479   55.0      4624
# 7270      137.0    361    7.0      3722
#
# [12407 rows x 4 columns]

# %%
ytrain
# Out:
# 3485     4.7
# 8701     5.2
# 11179    3.6
# 11628    7.6
# 4819     6.0
#         ...
# 5191     6.0
# 13418    6.0
# 5390     6.1
# 860      6.0
# 7270     3.7
# Name: Rating, Length: 12407, dtype: float64

# %% [markdown]
# # Linear Regression Model

# %%
lm=LinearRegression()
lm.fit(xtrain,ytrain)
ypred=lm.predict(xtest)

# %%
print("MAE",mean_absolute_error(ytest,ypred))
print("MSE",mean_squared_error(ytest,ypred))
print("r2 Score",r2_score(ytest,ypred))
# Out:
# MAE 0.5922119254179373
# MSE 0.9426768650351137
# r2 Score 0.03057649528920836

# %%
lm.predict(xtest.iloc[[1]])
# Out:
# array([5.93784069])

# %%
ytest.iloc[1]
# Out:
# np.float64(6.8)

# %% [markdown]
# > <b> The regression model shows weak predictive ability, with an MAE of 0.59 and an MSE of 0.94, indicating that predictions deviate from actual values by around half a unit on average with some larger errors. The very low R² score (0.030) highlights that the model explains less than 3% of the variance in the target variable, meaning it is only slightly better than using the mean as a prediction

# %% [markdown]
# ## RandomForest Regressor

# %%
rm=RandomForestRegressor(n_estimators=100,random_state=42)
rm.fit(xtrain,ytrain)
ypredr=rm.predict(xtest)

# %%
print("MAE",mean_absolute_error(ytest,ypredr))
print("MSE",mean_squared_error(ytest,ypredr))
print("r2 Score",r2_score(ytest,ypredr))
# Out:
# MAE 0.5103204384268214
# MSE 0.8452894198153521
# r2 Score 0.13072712161889433

# %%
rm.predict(xtest.iloc[[1]])
# Out:
# array([6.801])

# %%
ytest.iloc[1]
# Out:
# np.float64(6.8)

# %% [markdown]
# > <b> “The Random Forest Regressor achieved a Mean Absolute Error (MAE) of 0.51 and a Mean Squared Error (MSE) of 0.84, indicating that the model’s predictions deviate from the actual values by about half a unit on average. However, the R² score of 0.13 suggests that the model is able to explain only 13% of the variance in the target variable. This indicates that while the Random Forest model reduces prediction errors to some extent, it does not provide a strong fit for the data, and further improvements may be needed through feature engineering, parameter tuning, or trying alternative algorithms.”

# %% [markdown]
# ## SVR

# %%
svr=SVR(kernel='rbf',degree=3,gamma='scale', C=100, epsilon=0.1)
svr.fit(xtrain,ytrain)
ypreds=svr.predict(xtest)

# %%
print("MAE",mean_absolute_error(ytest,ypreds))
print("MSE",mean_squared_error(ytest,ypreds))
print("r2 Score",r2_score(ytest,ypreds))
# Out:
# MAE 0.5800164628323904
# MSE 0.9755864821944775
# r2 Score -0.0032668688461070516

# %%
svr.predict(xtest.iloc[[1]])
# Out:
# array([6.05044082])

# %%
ytest.iloc[1]
# Out:
# np.float64(6.8)

# %% [markdown]
# > <b> “The Support Vector Regressor (SVR) produced a Mean Absolute Error (MAE) of 0.58 and a Mean Squared Error (MSE) of 0.98, meaning that the predictions deviate from the actual values by more than half a unit on average. However, the R² score is −0.003, which is lower than zero, indicating that the SVR model performs worse than a simple baseline predictor (such as predicting the mean of the target). This shows that the SVR model does not capture the underlying data patterns effectively and is not suitable in its current form without further tuning or feature improvements

# %% [markdown]
# # Decision TreeRegressor

# %%
dr=DecisionTreeRegressor(criterion='squared_error',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=4,
    max_features='sqrt',
    random_state=42)
dr.fit(xtrain,ytrain)
ypredd=dr.predict(xtest)

# %%
print("MAE",mean_absolute_error(ytest,ypredd))
print("MSE",mean_squared_error(ytest,ypredd))
print("r2 Score",r2_score(ytest,ypredd))
# Out:
# MAE 0.5666012566428452
# MSE 0.8636243284125398
# r2 Score 0.11187199531835057

# %%
dr.predict(xtest.iloc[[1]])
# Out:
# array([6.09361243])

# %%
ytest.iloc[1]
# Out:
# np.float64(6.8)

# %% [markdown]
# > <b> Based on the evaluation metrics, the Decision Tree Regressor shows a Mean Absolute Error (MAE) of 0.5666 and a Mean Squared Error (MSE) of 0.8636, which indicates that the model’s predictions deviate moderately from the actual values. However, the R² score of 0.1119 reveals that the model is able to explain only about 11% of the variance in the target variable. This suggests that while the model is producing predictions with some level of accuracy, its overall explanatory power is quite low. In other words, the Decision Tree is not effectively capturing the underlying patterns in the dataset, and improvements such as hyperparameter tuning or using more advanced ensemble techniques may be necessary to achieve better performance.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Among the models tested, linear regression provided very weak predictive power with only a small portion of variance explained. Support Vector Regression performed the worst, with almost no ability to capture meaningful patterns. A single decision tree showed slight improvement but still remained limited due to its tendency to overfit and poor generalization. In contrast, ensemble methods like random forests are generally the most effective choice, as they combine multiple trees to capture nonlinear relationships and usually deliver stronger and more reliable predictive performance compared to the other approaches.
